# %%
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Ajouter le chemin vers la racine ou le dossier contenant generate_data.py
sys.path.append("..")  # Ajuster selon votre arborescence réelle

from src.generation import main

# Appel de la fonction principale qui génère et enregistre les données
main("Data/donnees_synthetiques.csv")

# %%
dfp = pd.read_csv("Data/preprocessed_data.csv")
dfing = pd.read_csv("Data/ingested_data.csv")

# %%
dfp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108120 entries, 0 to 108119
# Data columns (total 25 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Categorie_Electronique  108120 non-null  float64
#  1   Categorie_Livres        108120 non-null  float64
#  2   Categorie_Vetements     108120 non-null  float64
#  3   0                       108120 non-null  object
#  4   2                       108120 non-null  object
#  5   3                       108120 non-null  float64
#  6   4                       108120 non-null  float64
#  7   5                       108120 non-null  float64
#  8   6                       108120 non-null  int64
#  9   7                       108120 non-null  float64
#  10  8                       108120 non-null  int64
#  11  9                       108120 non-null  float64
#  12  10                      108120 non-null  float64
# ...

# %%
df = pd.read_csv("Data/donnees_synthetiques.csv")

# %%
df
# Out:
#             SKU     Categorie            Timestamp        Date        Prix  \
# 0        SKU1_1  Electronique  2023-06-25 00:00:00  2023-06-25  400.213693
# 1        SKU1_1  Electronique  2023-06-25 08:00:00  2023-06-25  399.600238
# 2        SKU1_1  Electronique  2023-06-25 16:00:00  2023-06-25  399.582706
# 3        SKU1_1  Electronique  2023-06-26 00:00:00  2023-06-26  398.145764
# 4        SKU1_1  Electronique  2023-06-26 08:00:00  2023-06-26  398.643126
# ...         ...           ...                  ...         ...         ...
# 108115  SKU3_20     Vetements  2025-02-13 00:00:00  2025-02-13   25.364485
# 108116  SKU3_20     Vetements  2025-02-13 08:00:00  2025-02-13   25.108658
# 108117  SKU3_20     Vetements  2025-02-13 16:00:00  2025-02-13   24.754759
# 108118  SKU3_20     Vetements  2025-02-14 00:00:00  2025-02-14   23.943199
# 108119  SKU3_20     Vetements  2025-02-14 08:00:00  2025-02-14   24.292858
#
#         PrixInitial  Remise  ErreurAleatoire  Promotion   Qualite  \
# ...

# %%
# figsize=(10, 6)
plt.figure(figsize=(10, 6))

# Exemple de visualisation
sns.lineplot(data=df, x='Date', y='Prix', hue='Categorie')
plt.title('Évolution du prix par catégorie')
plt.show()

# %%
data = df.query("SKU == 'SKU1_5'")
plt.figure(figsize=(10, 6))
sns.lineplot(data=data, x='Date', y='Prix', hue='Categorie')
plt.title('Évolution du prix par catégorie')
plt.show()
